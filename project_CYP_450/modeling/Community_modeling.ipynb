# %% [markdown]
# Imports needed to run the code

# %%
from cobra.io import read_sbml_model
from cobra.io import write_sbml_model
from mewpy.simulation import get_simulator
from mewpy.simulation import set_default_solver
from mewpy.model import CommunityModel 
from os import listdir
from os.path import isfile, join
from math import inf

set_default_solver('cplex')

# %% [markdown]
# Creating a comprehension list with the models that will be used in the community model

# %%
FOLDER = 'models'
m = [f for f in listdir(FOLDER) if isfile(join(FOLDER, f))]

# %% [markdown]
# Read, rename and open all drains for each organism model

# %%
models = []
for f in m:
    
    # load the models
    model = read_sbml_model(join(FOLDER, f))
    
    # rename the models
    model.id = f[:-4]
    
    # open all exchange reactions
    sim = get_simulator(model)
    for r_id in sim.get_exchange_reactions():
        sim.set_reaction_bounds(r_id,-inf,inf)
        
    models.append(sim.model)

# %% [markdown]
# Build the community model

# %%
cm = CommunityModel(models)

# %%
sim = cm.comm_model

# %% [markdown]
# Doing a pFBA to find a flux distribution that gives the optimal growth rate, while minimizing the total sum of the flux

# %%
res = sim.simulate(method='pFBA')
res
# Out:
# objective: 725724.1035309915
# Status: OPTIMAL
# Constraints: OrderedDict()
# Method:pFBA

# %% [markdown]
# Observing the biomass of the community model

# %%
# community biomass
res.find(cm.biomass)
# Out:
#                    Flux rate
# Reaction ID
# community_growth  1316.52876

# %% [markdown]
# Observing the biomass of each organism

# %%
res.find(list(cm.biomasses.values()))
# Out:
#                                                      Flux rate
# Reaction ID
# biomass525_Klebsiella_pneumoniae_pneumoniae_MGH...  107.795188
# biomass166_Bacillus_subtilis_str_168                123.692103
# biomass383_Kluyvera_ascorbata_ATCC_33433            157.498106
# biomass525_Clostridium_sp_7_2_43FAA                  91.462414
# biomass345_Escherichia_coli_SE11                    155.471927
# biomass360_Morganella_morganii_subsp_morganii_KT    151.471276
# biomass345_Bifidobacterium_longum_DJO10A             76.277167
# biomass402_Klebsiella_oxytoca_KCTC_1686             157.596633
# biomass386_Enterobacter_cloacae_EcWSU1              206.481381
# biomass524_Enterococcus_faecalis_TX0104              88.782567

# %% [markdown]
# Check the community model uptakes

# %%
up = [x[:-3] for x in sim.get_exchange_reactions()]

# %%
df.loc[df['lb']!=-inf]
# Out:
#                                    name   lb   ub              stoichiometry  \
# id
# community_growth  Community growth rate  0.0  inf  {'community_biomass': -1}
#
#                  gpr  Flux rate
# id
# community_growth       530.1671

# %% [markdown]
# Check all the reactions with a flux rate = 0

# %%
df=sim.find(up).join(res.find(up))
df.loc[df['Flux rate']==0]
# Out:
#                             name   lb   ub         stoichiometry gpr  \
# id
# EX_13ppd[e]          EX_13ppd[e] -inf  inf      {'13ppd[e]': -1}
# EX_15dap[e]          EX_15dap[e] -inf  inf      {'15dap[e]': -1}
# EX_2ddglcn[e]      EX_2ddglcn[e] -inf  inf    {'2ddglcn[e]': -1}
# EX_2hyoxplac[e]  EX_2hyoxplac[e] -inf  inf  {'2hyoxplac[e]': -1}
# EX_34dhpha[e]      EX_34dhpha[e] -inf  inf    {'34dhpha[e]': -1}
# ...                          ...  ...  ...                   ...  ..
# EX_dextrin[e]      EX_dextrin[e] -inf  inf    {'dextrin[e]': -1}
# EX_glctnb[e]        EX_glctnb[e] -inf  inf     {'glctnb[e]': -1}
# EX_thf[e]              EX_thf[e] -inf  inf        {'thf[e]': -1}
# EX_n2[e]                EX_n2[e] -inf  inf         {'n2[e]': -1}
# EX_chtbs[e]          EX_chtbs[e] -inf  inf      {'chtbs[e]': -1}
#
#                  Flux rate
# id
# EX_13ppd[e]           -0.0
# EX_15dap[e]           -0.0
# EX_2ddglcn[e]          0.0
# EX_2hyoxplac[e]       -0.0
# EX_34dhpha[e]         -0.0
# ...                    ...
# EX_dextrin[e]         -0.0
# EX_glctnb[e]           0.0
# EX_thf[e]             -0.0
# EX_n2[e]               0.0
# EX_chtbs[e]            0.0
#
# [559 rows x 6 columns]

# %% [markdown]
# Since all uptakes are open the community growth should have been unbounded.
# The models used probably need to be curated.

# %% [markdown]
# Creation of a minimal medium containing only the essential reactions

# %%
from cobra.medium.minimal_medium import minimal_medium
minimal_mediums = dict()
for m in models:
    medium =minimal_medium(sim.model,min_objective_value=0.1).to_dict()
    minimal_mediums[m.id]=medium

# %% [markdown]
# Select the uptakes needed for the model to grow

# %%
uptakes= set()
for r_exs in minimal_mediums.values():
    uptakes = uptakes.union(set(r_exs.keys()))
uptakes
# Out:
# {'EX_MGlcn65[e]',
#  'EX_MGlcn65_rl[e]',
#  'EX_amp[e]',
#  'EX_ca2[e]',
#  'EX_cl[e]',
#  'EX_cobalt2[e]',
#  'EX_cu2[e]',
#  'EX_fe2[e]',
#  'EX_fe3[e]',
#  'EX_k[e]',
#  'EX_mg2[e]',
#  'EX_mn2[e]',
#  'EX_nmn[e]',
#  'EX_pheme[e]',
#  'EX_sheme[e]',
#  'EX_so4[e]',
#  'EX_tet[e]',
#  'EX_thm[e]',
#  'EX_zn2[e]'}

# %%
medium = {k:(0,inf) for k in sim.get_uptake_reactions()}
medium.update({k:(-inf,inf) for k in uptakes})

# %% [markdown]
# Runing a pFBA with the minimal medium obtained

# %%
res = sim.simulate(method='pFBA',constraints=medium)
res.find(list(cm.biomasses.values()))
# Out:
#                                                      Flux rate
# Reaction ID
# biomass525_Klebsiella_pneumoniae_pneumoniae_MGH...   88.439737
# biomass166_Bacillus_subtilis_str_168                  0.000000
# biomass383_Kluyvera_ascorbata_ATCC_33433            107.205988
# biomass525_Clostridium_sp_7_2_43FAA                   0.000000
# biomass345_Escherichia_coli_SE11                     83.103535
# biomass360_Morganella_morganii_subsp_morganii_KT     79.283456
# biomass345_Bifidobacterium_longum_DJO10A              0.000000
# biomass402_Klebsiella_oxytoca_KCTC_1686             140.940773
# biomass386_Enterobacter_cloacae_EcWSU1              118.059595
# biomass524_Enterococcus_faecalis_TX0104               0.000000

# %% [markdown]
# If we only allow for uptakes that are essential for each organisms individualy, some do not grow
#
# Organisms with faster metabolisms prevent other to grow

# %% [markdown]
# Code developed to enrich the medium

# %%
res = sim.simulate(method='pFBA')
print(res)
not_used = [x for x in sim.get_uptake_reactions() if res.fluxes[x]==0]
print('N. of external metabolites not used:',len(not_used))
# Out:
# objective: 725724.1035310331
# Status: OPTIMAL
# Constraints: OrderedDict()
# Method:pFBA
# N. of external metabolites not used: 561

# %% [markdown]
# Defining a minimal medium

# %%
m=minimal_medium(sim.model,min_objective_value=1.0).to_dict()
m
# Out:
# {'EX_ca2[e]': 0.0030965,
#  'EX_cl[e]': 0.0030965,
#  'EX_cobalt2[e]': 0.0030965,
#  'EX_cu2[e]': 0.0030965,
#  'EX_fe3[e]': 0.006193,
#  'EX_k[e]': 0.0030965,
#  'EX_mg2[e]': 0.0030965,
#  'EX_mn2[e]': 0.0030965,
#  'EX_nmn[e]': 0.30810650000177975,
#  'EX_so4[e]': 0.0030965,
#  'EX_thm[e]': 0.0030965,
#  'EX_zn2[e]': 0.0030965,
#  'EX_pheme[e]': 0.0030965,
#  'EX_amp[e]': 0.5039670000015443,
#  'EX_sheme[e]': 0.0030965,
#  'EX_MGlcn65_rl[e]': 1.078158499999669,
#  'EX_tet[e]': 0.054083000000019865}

# %% [markdown]
# Check if from the new medium there is any uptake that it's now used but previously wasn't

# %%
intersect = set(m.keys()).intersection(set(not_used))
intersect
# Out:
# {'EX_MGlcn65_rl[e]', 'EX_tet[e]'}

# %% [markdown]
# Adding the new uptakes to a list with other used ones

# %%
not_used = list(set(not_used)-intersect)
used = [x for x in sim.get_uptake_reactions() if x not in not_used]
print('N. of external metabolites used:',len(used))
# Out:
# N. of external metabolites used: 120

# %% [markdown]
# Runing pFBA

# %%
medium={x:0 for x in not_used}
medium.update({x:(-inf,inf) for x in used})

res = sim.simulate(method='pFBA',constraints=medium)
res.find(list(cm.biomasses.values()))
# Out:
#                                                      Flux rate
# Reaction ID
# biomass525_Klebsiella_pneumoniae_pneumoniae_MGH...  107.795188
# biomass166_Bacillus_subtilis_str_168                123.692103
# biomass383_Kluyvera_ascorbata_ATCC_33433            157.498106
# biomass525_Clostridium_sp_7_2_43FAA                  91.462414
# biomass345_Escherichia_coli_SE11                    155.471927
# biomass360_Morganella_morganii_subsp_morganii_KT    151.471276
# biomass345_Bifidobacterium_longum_DJO10A             76.277167
# biomass402_Klebsiella_oxytoca_KCTC_1686             157.596633
# biomass386_Enterobacter_cloacae_EcWSU1              206.481381
# biomass524_Enterococcus_faecalis_TX0104              88.782567

# %% [markdown]
# Imports needed to make the optimization problem to find the best medium for the community model

# %%
from mewpy.problems import MediumProblem
from mewpy.optimization.evaluation import MolecularWeight, CNRFA, TargetFlux
import numpy as np

# %% [markdown]
# Creating the optimization problem

# %%
# list with the uptake reactions
uptakes = used

# list with the biomasses of the organisms
biomasses = list(cm.biomasses.values())

# Optimization Objectives:
##########################

# Minimize the uptakes of the Molecular Weight
f1 = MolecularWeight(uptakes,maximize=False)

# Maximize the number of organisms growing above 0.1 1/h
f2 = CNRFA(biomasses,maximize=True)

# Minimize the community growth
f3 = TargetFlux(cm.biomass,maximize=False)


# close all uptakes
for rx in sim.get_uptake_reactions():
    sim.set_reaction_bounds(rx,0,0)

n = len(uptakes)

# Possible maximum uptake rates in [0,10,20,30,...,300]
levels = np.linspace(0, 300, 31)


problem = MediumProblem(sim.model,
                        [f1,f2,f3],
                        candidate_min_size=n, 
                        candidate_max_size=n, 
                        target=uptakes,
                        levels = levels
                       )

# %% [markdown]
# Runing the optimization problem with the help of Evolutionary Algorithm (EA)

# %%
from mewpy.optimization import EA

ea = EA(problem)
# solutions = ea.run()

# %% [markdown]
# Read the result of the EA

# %%
import pandas as pd
df = pd.read_csv('medium.csv',index_col=0)
df
# Out:
#                                          Modification  Size  Molecular Weight  \
# ID
# 1   {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 70.0, 'EX_...    83       1907.006040
# 26  {'EX_galct_D[e]': 30.0, 'EX_dcyt[e]': 10.0, 'E...    90       2214.558517
# 35  {'EX_cl[e]': 50.0, 'EX_gthrd[e]': 290.0, 'EX_f...    94       2527.907592
# 57  {'EX_cl[e]': 70.0, 'EX_gthrd[e]': 290.0, 'EX_f...    94       2672.459385
# 36  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 70.0, 'EX_...    87       2687.744001
# 39  {'EX_cl[e]': 70.0, 'EX_fol[e]': 30.0, 'EX_ser_...    96       2905.641341
# 2   {'EX_nmn[e]': 240.0, 'EX_ppa[e]': 70.0, 'EX_gl...   112       3325.798791
# 25  {'EX_cl[e]': 70.0, 'EX_ppi[e]': 270.0, 'EX_ac[...   107       3443.949736
# 22  {'EX_cl[e]': 50.0, 'EX_acac[e]': 220.0, 'EX_ma...   117       3455.974329
# 18  {'EX_cl[e]': 70.0, 'EX_acac[e]': 140.0, 'EX_ma...   114       3855.830389
# 17  {'EX_acac[e]': 220.0, 'EX_man6p[e]': 250.0, 'E...   121       4247.154995
# 50  {'EX_acac[e]': 220.0, 'EX_ppi[e]': 290.0, 'EX_...   122       4433.526005
# 46  {'EX_acac[e]': 220.0, 'EX_ppi[e]': 290.0, 'EX_...   125       4465.739055
# 32  {'EX_ppi[e]': 290.0, 'EX_man6p[e]': 250.0, 'EX...   126       4536.950281
# 23  {'EX_acac[e]': 140.0, 'EX_ala_L[e]': 280.0, 'E...   117       4773.312955
# 49  {'EX_cl[e]': 60.0, 'EX_acac[e]': 140.0, 'EX_pp...   119       4813.806874
# 40  {'EX_acac[e]': 220.0, 'EX_man6p[e]': 250.0, 'E...   126       4984.710011
# 4   {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    86       1803.258718
# 19  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 70.0, 'EX_...    88       2349.577887
# 3   {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 70.0, 'EX_...    94       3139.508639
# 5   {'EX_cl[e]': 70.0, 'EX_ser_L[e]': 110.0, 'EX_a...    88        464.550746
# 21  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    88        979.251557
# 47  {'EX_sheme[e]': 250.0, 'EX_galct_D[e]': 30.0, ...    93       1087.545818
# 44  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 50.0, 'EX_...    90       1092.330749
# 53  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    87       1110.750131
# 29  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    91       1139.996618
# 33  {'EX_galct_D[e]': 30.0, 'EX_h2[e]': 170.0, 'EX...    90       1226.761369
# 38  {'EX_cl[e]': 170.0, 'EX_gthrd[e]': 250.0, 'EX_...    87       1246.286926
# 42  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    89       1267.009554
# 16  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    91       1350.867797
# 15  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    88       1451.202000
# 6   {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 70.0, 'EX_...    81       1590.661514
# 31  {'EX_cl[e]': 70.0, 'EX_acac[e]': 140.0, 'EX_bh...    99        283.489662
# 30  {'EX_cl[e]': 60.0, 'EX_acac[e]': 140.0, 'EX_se...    92        557.657665
# 48  {'EX_sheme[e]': 260.0, 'EX_cgly[e]': 80.0, 'EX...    87        563.921640
# 20  {'EX_sheme[e]': 260.0, 'EX_galct_D[e]': 30.0, ...    93        634.181107
# 24  {'EX_sheme[e]': 260.0, 'EX_cgly[e]': 270.0, 'E...    91        658.374181
# 37  {'EX_sheme[e]': 250.0, 'EX_cgly[e]': 270.0, 'E...    89        725.352546
# 41  {'EX_galct_D[e]': 30.0, 'EX_ribflv[e]': 210.0,...    90        755.106840
# 43  {'EX_cl[e]': 60.0, 'EX_ala_L[e]': 250.0, 'EX_t...    80        777.306699
# 27  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    87        887.920878
# 51  {'EX_sheme[e]': 50.0, 'EX_cgly[e]': 270.0, 'EX...    94        985.777481
# 52  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    89       1034.017785
# 7   {'EX_cl[e]': 170.0, 'EX_ppi[e]': 270.0, 'EX_dc...    90       1220.760304
# 13  {'EX_galct_D[e]': 30.0, 'EX_ala_L[e]': 250.0, ...    91        109.046478
# 58  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 170.0, 'EX...    91        335.390751
# 45  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    90        431.945963
# 28  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    87        505.239760
# 55  {'EX_galct_D[e]': 30.0, 'EX_cl[e]': 60.0, 'EX_...    87        516.362643
# 56  {'EX_cgly[e]': 270.0, 'EX_cl[e]': 60.0, 'EX_bu...    93        535.361391
# 12  {'EX_sheme[e]': 260.0, 'EX_galct_D[e]': 160.0,...    90        901.447189
# 9   {'EX_cgly[e]': 270.0, 'EX_galct_D[e]': 30.0, '...    90         35.212776
# 54  {'EX_galct_D[e]': 290.0, 'EX_acac[e]': 140.0, ...    92        122.584956
# 34  {'EX_cl[e]': 70.0, 'EX_ser_L[e]': 130.0, 'EX_a...    91        180.387023
# 8   {'EX_cl[e]': 70.0, 'EX_acac[e]': 140.0, 'EX_bh...   101        370.318286
# 14  {'EX_bhb[e]': 40.0, 'EX_mg2[e]': 60.0, 'EX_no2...    94        155.819107
# 60  {'EX_cl[e]': 170.0, 'EX_ala_L[e]': 240.0, 'EX_...    81        355.984284
# 59  {'EX_cl[e]': 70.0, 'EX_acac[e]': 140.0, 'EX_al...    89        356.980715
# 11  {'EX_pi[e]': 0.0, 'EX_glymet[e]': 120.0, 'EX_d...    90        484.845012
# 10  {'EX_cl[e]': 50.0, 'EX_acac[e]': 20.0, 'EX_gth...    84        257.413095
#
#     CNRFA  TargetFlux
# ID
# 1      10  686.601857
# 26     10  705.815107
# 35     10  714.505771
# 57     10  723.166452
# 36     10  723.817187
# 39     10  739.893197
# 2      10  538.235154
# 25     10  744.846974
# 22     10  760.076793
# 18     10  769.603352
# 17     10  772.810460
# 50     10  780.277806
# 46     10  782.235809
# 32     10  790.053006
# 23     10  792.809274
# 49     10  798.410717
# 40     10  802.772121
# 4       9  608.773231
# 19      9  716.015356
# 3       9  743.895398
# 5       6  124.088134
# 21      6  285.403109
# 47      6  335.038684
# 44      6  357.111667
# 53      6  381.739940
# 29      6  381.740153
# 33      6  418.682632
# 38      6  443.311483
# 42      6  459.127179
# 16      6  467.939470
# 15      6  529.510157
# 6       6  549.449139
# 31      5   86.199298
# 30      5  135.456661
# 48      5  197.027752
# 20      5  198.541989
# 24      5  233.970117
# 37      5  246.284268
# 41      5  272.995070
# 43      5  283.226577
# 27      5  320.169109
# 51      5  332.483477
# 52      5  369.426037
# 7       5  430.997171
# 13      4   36.942658
# 58      4   98.513817
# 45      4  124.088740
# 28      4  172.399362
# 55      4  172.399399
# 56      4  186.132164
# 12      4  322.630518
# 9       3   12.314247
# 54      3   36.942742
# 34      3   49.256989
# 8       3   98.513978
# 14      2   49.256504
# 60      2  110.827648
# 59      2  123.141919
# 11      2  135.456421
# 10      1   86.199731

# %% [markdown]
# Selecting the best medium to use for the modelling

# %%
solution = eval(df.loc[1]['Modification'])
solution
# Out:
# {'EX_galct_D[e]': 30.0,
#  'EX_cl[e]': 70.0,
#  'EX_ser_L[e]': 270.0,
#  'EX_dcyt[e]': 10.0,
#  'EX_sucr[e]': 0.0,
#  'EX_nmn[e]': 230.0,
#  'EX_trp_L[e]': 30.0,
#  'EX_lac_L[e]': 90.0,
#  'EX_mal_L[e]': 0.0,
#  'EX_fol[e]': 290.0,
#  'EX_cit[e]': 50.0,
#  'EX_cu2[e]': 120.0,
#  'EX_fe2[e]': 180.0,
#  'EX_alahis[e]': 150.0,
#  'EX_nac[e]': 60.0,
#  'EX_oxa[e]': 170.0,
#  'EX_tsul[e]': 70.0,
#  'EX_pnto_R[e]': 190.0,
#  'EX_k[e]': 20.0,
#  'EX_ppa[e]': 230.0,
#  'EX_orn[e]': 300.0,
#  'EX_na1[e]': 80.0,
#  'EX_o2[e]': 30.0,
#  'EX_ac[e]': 110.0,
#  'EX_fe3[e]': 100.0,
#  'EX_duri[e]': 50.0,
#  'EX_xan[e]': 260.0,
#  'EX_4abz[e]': 200.0,
#  'EX_asn_L[e]': 240.0,
#  'EX_mg2[e]': 60.0,
#  'EX_sel[e]': 230.0,
#  'EX_val_L[e]': 150.0,
#  'EX_dgsn[e]': 90.0,
#  'EX_glypro[e]': 60.0,
#  'EX_mqn7[e]': 80.0,
#  'EX_g6p[e]': 70.0,
#  'EX_pheme[e]': 280.0,
#  'EX_26dap_M[e]': 0.0,
#  'EX_so4[e]': 270.0,
#  'EX_glyasn[e]': 270.0,
#  'EX_MGlcn181[e]': 210.0,
#  'EX_thymd[e]': 180.0,
#  'EX_cytd[e]': 160.0,
#  'EX_arg_L[e]': 50.0,
#  'EX_tyr_L[e]': 70.0,
#  'EX_ca2[e]': 270.0,
#  'EX_cobalt2[e]': 200.0,
#  'EX_zn2[e]': 210.0,
#  'EX_csn[e]': 20.0,
#  'EX_thr_L[e]': 130.0,
#  'EX_gln_L[e]': 120.0,
#  'EX_hxan[e]': 160.0,
#  'EX_ddca[e]': 50.0,
#  'EX_metsox_S_L[e]': 10.0,
#  'EX_melib[e]': 100.0,
#  'EX_pi[e]': 300.0,
#  'EX_pydx[e]': 180.0,
#  'EX_h2s[e]': 130.0,
#  'EX_12ppd_S[e]': 220.0,
#  'EX_MGlcn193[e]': 0.0,
#  'EX_asp_L[e]': 200.0,
#  'EX_glu_L[e]': 10.0,
#  'EX_ile_L[e]': 120.0,
#  'EX_MGlcn65_rl[e]': 210.0,
#  'EX_ade[e]': 140.0,
#  'EX_etoh[e]': 170.0,
#  'EX_sheme[e]': 250.0,
#  'EX_glcn[e]': 130.0,
#  'EX_mn2[e]': 240.0,
#  'EX_etha[e]': 280.0,
#  'EX_cgly[e]': 80.0,
#  'EX_gcald[e]': 70.0,
#  'EX_glymet[e]': 170.0,
#  'EX_glyc3p[e]': 130.0,
#  'EX_uri[e]': 150.0,
#  'EX_ttdca[e]': 230.0,
#  'EX_ppi[e]': 270.0,
#  'EX_thm[e]': 10.0,
#  'EX_h[e]': 50.0,
#  'EX_h2o[e]': 70.0,
#  'EX_for[e]': 270.0,
#  'EX_so3[e]': 40.0,
#  'EX_adn[e]': 20.0}

# %% [markdown]
# Changing the format of the uptakes

# %%
const = {k:(0,inf) for k in sim.get_uptake_reactions()}
const.update({k : (-v,1000) for k,v in solution.items()})

# %% [markdown]
# Doing a pFBA with medium from the EA

# %%
res = sim.simulate(method='pFBA',constraints=const)
res.find(list(cm.biomasses.values()))
# Out:
#                                                      Flux rate
# Reaction ID
# biomass525_Klebsiella_pneumoniae_pneumoniae_MGH...    0.000000
# biomass166_Bacillus_subtilis_str_168                  8.474965
# biomass383_Kluyvera_ascorbata_ATCC_33433            110.382282
# biomass525_Clostridium_sp_7_2_43FAA                  20.137757
# biomass345_Escherichia_coli_SE11                     45.121717
# biomass360_Morganella_morganii_subsp_morganii_KT      0.000000
# biomass345_Bifidobacterium_longum_DJO10A              0.000000
# biomass402_Klebsiella_oxytoca_KCTC_1686              56.528968
# biomass386_Enterobacter_cloacae_EcWSU1              141.326013
# biomass524_Enterococcus_faecalis_TX0104               8.672611

# %% [markdown]
# Comand SteadyCom implemented in MEWpy predict changes in the species abundance
#
# The medium in this first simulation a open one (batch)

# %%
from mewpy.cobra.steadycom import SteadyCom
SteadyCom(cm)
# Out:
# Community growth: 206.48046874999997
# Klebsiella_pneumoniae_pneumoniae_MGH78578	0.0
# Bacillus_subtilis_str_168	0.0
# Kluyvera_ascorbata_ATCC_33433	0.0
# Clostridium_sp_7_2_43FAA	0.0
# Escherichia_coli_SE11	0.0
# Morganella_morganii_subsp_morganii_KT	0.0
# Bifidobacterium_longum_DJO10A	0.0
# Klebsiella_oxytoca_KCTC_1686	0.0
# Enterobacter_cloacae_EcWSU1	1.0
# Enterococcus_faecalis_TX0104	0.0

# %% [markdown]
# In batch medium the Enterobacter cloacae would take over all other organisms

# %% [markdown]
# Comand SteadyCom but this time we use the menimal medium obtained from the optimization problem

# %%
SteadyCom(cm,constraints=const)
# Out:
# Community growth: 103.96289062499997
# Klebsiella_pneumoniae_pneumoniae_MGH78578	0.036119878517129465
# Bacillus_subtilis_str_168	0.0
# Kluyvera_ascorbata_ATCC_33433	0.15093323732430652
# Clostridium_sp_7_2_43FAA	0.0
# Escherichia_coli_SE11	0.316151197866958
# Morganella_morganii_subsp_morganii_KT	0.0
# Bifidobacterium_longum_DJO10A	0.0
# Klebsiella_oxytoca_KCTC_1686	0.25611987851712953
# Enterobacter_cloacae_EcWSU1	0.2406758077744766
# Enterococcus_faecalis_TX0104	0.0
